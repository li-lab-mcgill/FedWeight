# %%
import matplotlib.pyplot as plt

# Data for scatter plot
topics = ["64", "128", "192", "256", "320", "384", "448", "512", "576", "640"]
etm_quality = [
    0.2705527126869071, 0.21726310779302052, 0.18660180616072664,
    0.16401311057474532, 0.18266332733380886, 0.17307459641208153,
    0.1439003765567346, 0.17241685904960824, 0.1561604681594345,
    0.1459884151596959
]
fedavg_etm_quality = [
    0.29891665119039085, 0.2444816394103714, 0.211715330773125,
    0.18483400670194403, 0.1733558085693152, 0.17438420479892985,
    0.15467296082493173, 0.1776051069731069, 0.16657102244494143,
    0.1720298816998781
]
fedweight_etm_quality = [
    0.3224582310676761, 0.25373009113917866, 0.22377863644015483,
    0.20363872130772537, 0.19570429161436378, 0.18131052821774066,
    0.1754825940321322, 0.177949108546763, 0.17437877701343524,
    0.16761317815558674
]

# Create scatter plot
plt.figure(figsize=(6.5, 5))
plt.plot(topics, etm_quality, label='ETM', marker='o', linestyle='-', color='green')
plt.scatter(topics, etm_quality, marker='o', s=50, color='green')

plt.plot(topics, fedavg_etm_quality, label='FedAvg ETM', marker='s', linestyle='-', color='orange')
plt.scatter(topics, fedavg_etm_quality, marker='s', s=50, color='orange')

plt.plot(topics, fedweight_etm_quality, label='FedWeight ETM', marker='^', linestyle='-', color='blue')
plt.scatter(topics, fedweight_etm_quality, marker='^', s=50, color='blue')

# Add labels and title
plt.title('Topic Quality (Topic Coherence x Topic Diversity) on eICU Dataset')
plt.xlabel('Topics')
plt.ylabel('Topic Quality')
plt.xticks(topics)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for scatter plot
topics = ["64", "128", "192", "256", "320", "384", "448", "512", "576", "640"]
etm_quality = [
    0.32485931586598127, 0.26799434100972186, 0.19526590312526657,
    0.18548396146682217, 0.16716072781425204, 0.17226234353180325,
    0.18036398017178376, 0.18059770926441301, 0.18394955044713301,
    0.17023819709087054
]
fedavg_etm_quality = [
    0.3278475150219971, 0.24207445495254898, 0.19611025795369574,
    0.17830846627979977, 0.15931149424407973, 0.1652938465591811,
    0.1487476439849784, 0.16301693404533027, 0.16138698037057528,
    0.14942019790240768
]
fedweight_etm_quality = [
    0.34123113113631487, 0.26541214340733665, 0.2177740002991985,
    0.1893813027229924, 0.1780504336235931, 0.16746727083272928,
    0.16659783014310386, 0.17114979176330566, 0.16659855282454583,
    0.15046777228037636
]


# Create scatter plot
plt.figure(figsize=(6.5, 5))
plt.plot(topics, etm_quality, label='ETM', marker='o', linestyle='-', color='green')
plt.scatter(topics, etm_quality, marker='o', s=50, color='green')

plt.plot(topics, fedavg_etm_quality, label='FedAvg ETM', marker='s', linestyle='-', color='orange')
plt.scatter(topics, fedavg_etm_quality, marker='s', s=50, color='orange')

plt.plot(topics, fedweight_etm_quality, label='FedWeight ETM', marker='^', linestyle='-', color='blue')
plt.scatter(topics, fedweight_etm_quality, marker='^', s=50, color='blue')

# Add labels and title
plt.title('Topic Quality (Topic Coherence x Topic Diversity) on MIMIC Dataset')
plt.xlabel('Topics')
plt.ylabel('Topic Quality')
plt.xticks(topics)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for scatter plot
topics = ["64", "128", "192", "256", "320", "384", "448", "512", "576", "640"]
etm_quality = [
    0.1194, 0.1137, 0.1146, 0.1347, 0.1416, 0.1252, 0.1179, 0.1372, 0.1226, 0.1323
]
fedavg_etm_quality = [
    0.1179, 0.1241, 0.1251, 0.1161, 0.1144, 0.1154, 0.1208, 0.1147, 0.1263, 0.1267
]

fedweight_etm_quality = [
    0.1402, 0.1253, 0.1150, 0.1182, 0.1289, 0.1238, 0.1260, 0.1186, 0.1209, 0.1208
]

# Create scatter plot
plt.figure(figsize=(6.5, 5))
plt.plot(topics, etm_quality, label='ETM', marker='o', linestyle='-', color='green')
plt.scatter(topics, etm_quality, marker='o', s=50, color='green')

plt.plot(topics, fedavg_etm_quality, label='FedAvg ETM', marker='s', linestyle='-', color='orange')
plt.scatter(topics, fedavg_etm_quality, marker='s', s=50, color='orange')

plt.plot(topics, fedweight_etm_quality, label='FedWeight ETM', marker='^', linestyle='-', color='blue')
plt.scatter(topics, fedweight_etm_quality, marker='^', s=50, color='blue')

# Add labels and title
plt.title('AUPRC of Mortality Prediction after Re-admission using KNN (MIMIC on eICU)')
plt.xlabel('Topics')
plt.ylabel('AUPRC')
plt.xticks(topics)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for scatter plot
topics = ["64", "128", "192", "256", "320", "384", "448", "512", "576", "640"]
etm_quality = [
    0.2061, 0.1910, 0.1997, 0.1949, 0.2091, 0.1951, 0.1996, 0.2001, 0.1875, 0.1965
]
fedavg_etm_quality = [
    0.2083, 0.2000, 0.1914, 0.1955, 0.1853, 0.1837, 0.1956, 0.1894, 0.1860, 0.1951
]

fedweight_etm_quality = [
    0.1983, 0.1819, 0.1906, 0.1844, 0.1825, 0.1910, 0.1758, 0.1782, 0.2123, 0.1906
]

# Create scatter plot
plt.figure(figsize=(6, 5))
plt.plot(topics, etm_quality, label='ETM', marker='o', linestyle='-', color='green')
plt.scatter(topics, etm_quality, marker='o', s=50, color='green')

plt.plot(topics, fedavg_etm_quality, label='FedAvg ETM', marker='s', linestyle='-', color='orange')
plt.scatter(topics, fedavg_etm_quality, marker='s', s=50, color='orange')

plt.plot(topics, fedweight_etm_quality, label='FedWeight ETM', marker='^', linestyle='-', color='blue')
plt.scatter(topics, fedweight_etm_quality, marker='^', s=50, color='blue')

# Add labels and title
plt.title('AUPRC of Mortality Prediction after Re-admission using KNN (eICU on MIMIC)')
plt.xlabel('Topics')
plt.ylabel('AUPRC')
plt.xticks(topics)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()
